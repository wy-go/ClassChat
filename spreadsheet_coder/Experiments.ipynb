# %% [markdown]
# <a href="https://colab.research.google.com/github/wy-go/ClassChat/blob/main/spreadsheet_coder/Experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data
# Load data from [[UI]](https://console.cloud.google.com/storage/browser/spreadsheet_coder)
#
# ## Copy files from GCS with gsutil

# %%
from google.colab import auth
auth.authenticate_user()

# https://cloud.google.com/resource-manager/docs/creating-managing-projects
project_id = 'sheetcoder'
# !gcloud config set project {project_id}
# Out:
# Updated property [core/project].

# %%
# Download the file from a given Google Cloud Storage bucket.
# !gsutil -m cp -r \
  "gs://spreadsheet_coder/enron/" \
  .
  
# Print the result to make sure the transfer worked.
# !cat /sheetcoder/data/formulas_0_5.tf_record
# Out:
# Copying gs://spreadsheet_coder/enron/formulas_0_5.tf_record...
# Copying gs://spreadsheet_coder/enron/formulas_10_15.tf_record...
# Copying gs://spreadsheet_coder/enron/formulas_15_20.tf_record...
# Copying gs://spreadsheet_coder/enron/formulas_5_10.tf_record...
# Copying gs://spreadsheet_coder/enron/formulas_20_25.tf_record...
# Copying gs://spreadsheet_coder/enron/formulas_25_30.tf_record...
# / [6/6 files][  3.9 GiB/  3.9 GiB] 100% Done  23.4 MiB/s ETA 00:00:00
# Operation completed over 6 objects/3.9 GiB.

# %% [markdown]
# ## Read the TFRecord files

# %%
import tensorflow as tf
import os

data_dir = 'enron/'
tfrecord_files = [data_dir + filename for filename in os.listdir(data_dir)]
raw_dataset = tf.data.TFRecordDataset(tfrecord_files)

# Show the first 10 records.
for raw_record in raw_dataset.take(10):
  print(repr(raw_record))
# Out:
# ['enron/formulas_25_30.tf_record', 'enron/formulas_20_25.tf_record', 'enron/formulas_5_10.tf_record', 'enron/formulas_0_5.tf_record', 'enron/formulas_15_20.tf_record', 'enron/formulas_10_15.tf_record']
# <tf.Tensor: shape=(), dtype=string, numpy=b"\n\xdci\n\x12\n\tcol_index\x12\x05\x1a\x03\n\x01\x13\n\x0e\n\x06doc_id\x12\x04\n\x02\n\x00\n\x1b\n\x06header\x12\x11\n\x0f\n\rContract Cost\n\xdad\n\x0ccontext_data\x12\xc9d\n\xc6d\n\xc3d$R[-1]C[-10]$userEnteredValue=empty$$R[-1]C[-9]$userEnteredValue=empty$$R[-1]C[-8]$userEnteredValue=empty$$R[-1]C[-7]$userEnteredValue=empty$$R[-1]C[-6]$userEnteredValue=empty$$R[-1]C[-5]$userEnteredValue=empty$$R[-1]C[-4]$userEnteredValue=empty$$R[-1]C[-3]$userEnteredValue=empty$$R[-1]C[-2]$userEnteredValue=empty$$R[-1]C[-1]$userEnteredValue=empty$$R[-1]C[0]$userEnteredValue=empty$$R[-1]C[1]$userEnteredValue=empty$$R[-1]C[2]$userEnteredValue=empty$$R[-1]C[3]$userEnteredValue=empty$$R[-1]C[4]$userEnteredValue=empty$$R[0]C[-10]$userEnteredValue=str:New$$R[0]C[-9]$userEnteredValue=doub:37165.0$$R[0]C[-8]$userEnteredValue=str:Whitewing$$R[0]C[-7]$userEnteredValue=str:$4.5MM DASHed$$R[0]C[-6]$userEnteredValue=str:N$$R[0]C[-5]$userEnteredValue=str:N/A$$R[0]C[-4]$userEnteredValue=str:EWS$$R[0]C[-3]$userEnteredValue=str:John Chappell$$R[0]C[-2]$userEnteredValue=str:Stephen Heck$$R[0]C[-1]$userEnteredValue=str:Sale in Process$$R[0]C[0]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[3]C[-17], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:83.41666666666667$$R[0]C[1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[3]C[13], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:54.220833333333346$$R[0]C[2]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[4]C[12], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:49.215833333333336$$R[0]C[3]$userEnteredValue=empty$$R[0]C[4]$userEnteredValue=str:DASH in progress.$$R[1]C[-10]$userEnteredValue=str:New$$R[1]C[-9]$userEnteredValue=doub:37196.0$$R[1]C[-8]$userEnteredValue=str:Whitewing$$R[1]C[-7]$userEnteredValue=str:$4.5MM DASHed$$R[1]C[-6]$userEnteredValue=str:N$$R[1]C[-5]$userEnteredValue=str:N/A$$R[1]C[-4]$userEnteredValue=str:EWS$$R[1]C[-3]$userEnteredValue=str:John Chappell$$R[1]C[-2]$userEnteredValue=str:Stephen Heck$$R[1]C[-1]$userEnteredValue=str:Sale in Process$$R[1]C[0]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[10]C[-17], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:83.41666666666667$$R[1]C[1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[10]C[13], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:54.220833333333346$$R[1]C[2]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[11]C[12], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:49.215833333333336$$R[1]C[3]$userEnteredValue=empty$$R[1]C[4]$userEnteredValue=str:DASH in progress.$$R[2]C[-10]$userEnteredValue=str:New$$R[2]C[-9]$userEnteredValue=doub:37226.0$$R[2]C[-8]$userEnteredValue=str:Whitewing$$R[2]C[-7]$userEnteredValue=str:$4.5MM DASHed$$R[2]C[-6]$userEnteredValue=str:N$$R[2]C[-5]$userEnteredValue=str:N/A$$R[2]C[-4]$userEnteredValue=str:EWS$$R[2]C[-3]$userEnteredValue=str:John Chappell$$R[2]C[-2]$userEnteredValue=str:Stephen Heck$$R[2]C[-1]$userEnteredValue=str:Sale in Process$$R[2]C[0]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[17]C[-17], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:83.41666666666667$$R[2]C[1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[17]C[13], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:54.220833333333346$$R[2]C[2]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[18]C[12],  ...
# <tf.Tensor: shape=(), dtype=string, numpy=b'\n\xbef\n/\n\x06header\x12%\n#\n!Contract Paid to Date\n(Scheduled)\n-\n\x0ecomputed_value\x12\x1b\n\x19\n\x17doub:54.220833333333346\n\x12\n\tcol_index\x12\x05\x1a\x03\n\x01\x14\n\xb6a\n\x0ccontext_data\x12\xa5a\n\xa2a\n\x9fa$R[-1]C[-10]$userEnteredValue=empty$$R[-1]C[-9]$userEnteredValue=empty$$R[-1]C[-8]$userEnteredValue=empty$$R[-1]C[-7]$userEnteredValue=empty$$R[-1]C[-6]$userEnteredValue=empty$$R[-1]C[-5]$userEnteredValue=empty$$R[-1]C[-4]$userEnteredValue=empty$$R[-1]C[-3]$userEnteredValue=empty$$R[-1]C[-2]$userEnteredValue=empty$$R[-1]C[-1]$userEnteredValue=empty$$R[-1]C[0]$userEnteredValue=empty$$R[-1]C[1]$userEnteredValue=empty$$R[-1]C[2]$userEnteredValue=empty$$R[-1]C[3]$userEnteredValue=empty$$R[0]C[-10]$userEnteredValue=doub:37165.0$$R[0]C[-9]$userEnteredValue=str:Whitewing$$R[0]C[-8]$userEnteredValue=str:$4.5MM DASHed$$R[0]C[-7]$userEnteredValue=str:N$$R[0]C[-6]$userEnteredValue=str:N/A$$R[0]C[-5]$userEnteredValue=str:EWS$$R[0]C[-4]$userEnteredValue=str:John Chappell$$R[0]C[-3]$userEnteredValue=str:Stephen Heck$$R[0]C[-2]$userEnteredValue=str:Sale in Process$$R[0]C[-1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[3]C[-17], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:83.41666666666667$$R[0]C[0]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[3]C[13], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:54.220833333333346$$R[0]C[1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[4]C[12], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:49.215833333333336$$R[0]C[2]$userEnteredValue=empty$$R[0]C[3]$userEnteredValue=str:DASH in progress.$$R[1]C[-10]$userEnteredValue=doub:37196.0$$R[1]C[-9]$userEnteredValue=str:Whitewing$$R[1]C[-8]$userEnteredValue=str:$4.5MM DASHed$$R[1]C[-7]$userEnteredValue=str:N$$R[1]C[-6]$userEnteredValue=str:N/A$$R[1]C[-5]$userEnteredValue=str:EWS$$R[1]C[-4]$userEnteredValue=str:John Chappell$$R[1]C[-3]$userEnteredValue=str:Stephen Heck$$R[1]C[-2]$userEnteredValue=str:Sale in Process$$R[1]C[-1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[10]C[-17], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:83.41666666666667$$R[1]C[0]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[10]C[13], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:54.220833333333346$$R[1]C[1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[11]C[12], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:49.215833333333336$$R[1]C[2]$userEnteredValue=empty$$R[1]C[3]$userEnteredValue=str:DASH in progress.$$R[2]C[-10]$userEnteredValue=doub:37226.0$$R[2]C[-9]$userEnteredValue=str:Whitewing$$R[2]C[-8]$userEnteredValue=str:$4.5MM DASHed$$R[2]C[-7]$userEnteredValue=str:N$$R[2]C[-6]$userEnteredValue=str:N/A$$R[2]C[-5]$userEnteredValue=str:EWS$$R[2]C[-4]$userEnteredValue=str:John Chappell$$R[2]C[-3]$userEnteredValue=str:Stephen Heck$$R[2]C[-2]$userEnteredValue=str:Sale in Process$$R[2]C[-1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[17]C[-17], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:83.41666666666667$$R[2]C[0]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[17]C[13], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:54.220833333333346$$R[2]C[1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[18]C[12], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:49.215833333333336$$R[2]C[2]$userEnter ...
# <tf.Tensor: shape=(), dtype=string, numpy=b'\n\xc5b\n\x0e\n\x06doc_id\x12\x04\n\x02\n\x00\n\x12\n\tcol_index\x12\x05\x1a\x03\n\x01\x15\n\xca\x02\n\x0econtext_header\x12\xb7\x02\n\xb4\x02\n\xb1\x02$C[-10]$Owner$C[-9]$DASH\nApproval\nDate$C[-8]$Notice to Proceed Given$C[-7]$Status of Financing$C[-6]$Controlled By$C[-5]$Originator / Developer$C[-4]$Project Manager$C[-3]$Project Name$C[-2]$Contract Cost$C[-1]$Contract Paid to Date\n(Scheduled)$C[0]$\nCancel-lation Payment$C[1]$Comments$C[2]$Status Update\n"\n\x06ranges\x12\x18\n\x16\n\x14G278457581!R[4]C[12]\n\'\n\x12formula_token_list\x12\x11\n\x0f\n\rb\'= +  RANGE\'\n$\n\x06header\x12\x1a\n\x18\n\x16\nCancel-lation Payment\n(\n\x07formula\x12\x1d\n\x1b\n\x19RANGE UPLUS FORMULA_START\n\xdb]\n\x0ccontext_data\x12\xca]\n\xc7]\n\xc4]$R[-1]C[-10]$userEnteredValue=empty$$R[-1]C[-9]$userEnteredValue=empty$$R[-1]C[-8]$userEnteredValue=empty$$R[-1]C[-7]$userEnteredValue=empty$$R[-1]C[-6]$userEnteredValue=empty$$R[-1]C[-5]$userEnteredValue=empty$$R[-1]C[-4]$userEnteredValue=empty$$R[-1]C[-3]$userEnteredValue=empty$$R[-1]C[-2]$userEnteredValue=empty$$R[-1]C[-1]$userEnteredValue=empty$$R[-1]C[0]$userEnteredValue=empty$$R[-1]C[1]$userEnteredValue=empty$$R[-1]C[2]$userEnteredValue=empty$$R[0]C[-10]$userEnteredValue=str:Whitewing$$R[0]C[-9]$userEnteredValue=str:$4.5MM DASHed$$R[0]C[-8]$userEnteredValue=str:N$$R[0]C[-7]$userEnteredValue=str:N/A$$R[0]C[-6]$userEnteredValue=str:EWS$$R[0]C[-5]$userEnteredValue=str:John Chappell$$R[0]C[-4]$userEnteredValue=str:Stephen Heck$$R[0]C[-3]$userEnteredValue=str:Sale in Process$$R[0]C[-2]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[3]C[-17], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:83.41666666666667$$R[0]C[-1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[3]C[13], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:54.220833333333346$$R[0]C[0]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[4]C[12], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:49.215833333333336$$R[0]C[1]$userEnteredValue=empty$$R[0]C[2]$userEnteredValue=str:DASH in progress.$$R[1]C[-10]$userEnteredValue=str:Whitewing$$R[1]C[-9]$userEnteredValue=str:$4.5MM DASHed$$R[1]C[-8]$userEnteredValue=str:N$$R[1]C[-7]$userEnteredValue=str:N/A$$R[1]C[-6]$userEnteredValue=str:EWS$$R[1]C[-5]$userEnteredValue=str:John Chappell$$R[1]C[-4]$userEnteredValue=str:Stephen Heck$$R[1]C[-3]$userEnteredValue=str:Sale in Process$$R[1]C[-2]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[10]C[-17], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:83.41666666666667$$R[1]C[-1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[10]C[13], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:54.220833333333346$$R[1]C[0]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[11]C[12], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:49.215833333333336$$R[1]C[1]$userEnteredValue=empty$$R[1]C[2]$userEnteredValue=str:DASH in progress.$$R[2]C[-10]$userEnteredValue=str:Whitewing$$R[2]C[-9]$userEnteredValue=str:$4.5MM DASHed$$R[2]C[-8]$userEnteredValue=str:N$$R[2]C[-7]$userEnteredValue=str:N/A$$R[2]C[-6]$userEnteredValue=str:EWS$$R[2]C[-5]$userEnteredValue=str:John Chappell$$R[2]C[-4]$userEnteredValue=str:Stephen Heck$$R[2]C[-3]$userEnteredValue=str:Sale in Process$$R[2]C[-2]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[17]C[-17], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:83.41666666666667$$R[2]C[-1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1F ...
# <tf.Tensor: shape=(), dtype=string, numpy=b"\n\xee[\n!\n\x06ranges\x12\x17\n\x15\n\x13R[0]C[-4]:R[0]C[-1]\n\x12\n\tcol_index\x12\x05\x1a\x03\n\x01\t\n\x11\n\x08table_id\x12\x05\x1a\x03\n\x01\x11\n,\n\x12formula_token_list\x12\x16\n\x14\n\x12b'=SUM(  RANGE ) '\n\x1e\n\x0ecomputed_value\x12\x0c\n\n\n\x08doub:0.0\n\x0e\n\x06doc_id\x12\x04\n\x02\n\x00\n\xbeW\n\x0ccontext_data\x12\xadW\n\xaaW\n\xa7W$R[0]C[-5]$userEnteredValue=str:vacant 11/24$$R[0]C[-4]$userEnteredValue=empty$$R[0]C[-3]$userEnteredValue=empty$$R[0]C[-2]$userEnteredValue=empty$$R[0]C[-1]$userEnteredValue=empty$$R[0]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[0]C[1]$userEnteredValue=empty$$R[0]C[2]$userEnteredValue=empty$$R[0]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[0]C[4]$userEnteredValue=empty$$R[0]C[5]$userEnteredValue=str:1/1$$R[0]C[6]$userEnteredValue=doub:0.0$$R[0]C[7]$userEnteredValue=empty$$R[0]C[8]$userEnteredValue=str:Huck-Jacobson$$R[0]C[9]$userEnteredValue=doub:175.0$$R[0]C[10]$userEnteredValue=doub:36704.0$$R[1]C[-5]$userEnteredValue=str:Rudy Longoria$$R[1]C[-4]$userEnteredValue=doub:0.0$$R[1]C[-3]$userEnteredValue=empty$$R[1]C[-2]$userEnteredValue=empty$$R[1]C[-1]$userEnteredValue=empty$$R[1]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[1]C[1]$userEnteredValue=empty$$R[1]C[2]$userEnteredValue=empty$$R[1]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[1]C[4]$userEnteredValue=str:220 bi-week 12/8 & 12/15$$R[1]C[5]$userEnteredValue=str:eff$$R[1]C[6]$userEnteredValue=doub:1.0$$R[1]C[7]$userEnteredValue=empty$$R[1]C[8]$userEnteredValue=empty$$R[1]C[9]$userEnteredValue=doub:175.0$$R[1]C[10]$userEnteredValue=doub:36301.0$$R[2]C[-5]$userEnteredValue=str:moved$$R[2]C[-4]$userEnteredValue=doub:250.0$$R[2]C[-3]$userEnteredValue=empty$$R[2]C[-2]$userEnteredValue=empty$$R[2]C[-1]$userEnteredValue=empty$$R[2]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[2]C[1]$userEnteredValue=empty$$R[2]C[2]$userEnteredValue=empty$$R[2]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[2]C[4]$userEnteredValue=str:$260 bi-weekly due 11/24 & 12/8.  missed 11/24 rent$$R[2]C[5]$userEnteredValue=str:2/1$$R[2]C[6]$userEnteredValue=doub:2.0$$R[2]C[7]$userEnteredValue=doub:1.0$$R[2]C[8]$userEnteredValue=str:Colonial Manor(Nurse Asst.)$$R[2]C[9]$userEnteredValue=doub:190.0$$R[2]C[10]$userEnteredValue=doub:36784.0$$R[3]C[-5]$userEnteredValue=str:Doris Copeland$$R[3]C[-4]$userEnteredValue=doub:0.0$$R[3]C[-3]$userEnteredValue=empty$$R[3]C[-2]$userEnteredValue=empty$$R[3]C[-1]$userEnteredValue=empty$$R[3]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[3]C[1]$userEnteredValue=empty$$R[3]C[2]$userEnteredValue=empty$$R[3]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1For ...
# <tf.Tensor: shape=(), dtype=string, numpy=b"\n\x99f\n*\n\x07formula\x12\x1f\n\x1d\n\x1bRANGE RANGE - FORMULA_START\n\x0e\n\x06doc_id\x12\x04\n\x02\n\x00\n\x11\n\x08table_id\x12\x05\x1a\x03\n\x01\x11\n\x15\n\x0crecord_index\x12\x05\x1a\x03\n\x01\x00\n\x1e\n\x0ecomputed_value\x12\x0c\n\n\n\x08doub:0.0\n\xc9a\n\x0ccontext_data\x12\xb8a\n\xb5a\n\xb2a$R[0]C[-8]$userEnteredValue=str:vacant 11/24$$R[0]C[-7]$userEnteredValue=empty$$R[0]C[-6]$userEnteredValue=empty$$R[0]C[-5]$userEnteredValue=empty$$R[0]C[-4]$userEnteredValue=empty$$R[0]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[0]C[-2]$userEnteredValue=empty$$R[0]C[-1]$userEnteredValue=empty$$R[0]C[0]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[0]C[1]$userEnteredValue=empty$$R[0]C[2]$userEnteredValue=str:1/1$$R[0]C[3]$userEnteredValue=doub:0.0$$R[0]C[4]$userEnteredValue=empty$$R[0]C[5]$userEnteredValue=str:Huck-Jacobson$$R[0]C[6]$userEnteredValue=doub:175.0$$R[0]C[7]$userEnteredValue=doub:36704.0$$R[0]C[8]$userEnteredValue=doub:36887.0$$R[0]C[9]$userEnteredValue=doub:120.0$$R[0]C[10]$userEnteredValue=str:weekly$$R[1]C[-8]$userEnteredValue=str:Rudy Longoria$$R[1]C[-7]$userEnteredValue=doub:0.0$$R[1]C[-6]$userEnteredValue=empty$$R[1]C[-5]$userEnteredValue=empty$$R[1]C[-4]$userEnteredValue=empty$$R[1]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[1]C[-2]$userEnteredValue=empty$$R[1]C[-1]$userEnteredValue=empty$$R[1]C[0]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[1]C[1]$userEnteredValue=str:220 bi-week 12/8 & 12/15$$R[1]C[2]$userEnteredValue=str:eff$$R[1]C[3]$userEnteredValue=doub:1.0$$R[1]C[4]$userEnteredValue=empty$$R[1]C[5]$userEnteredValue=empty$$R[1]C[6]$userEnteredValue=doub:175.0$$R[1]C[7]$userEnteredValue=doub:36301.0$$R[1]C[8]$userEnteredValue=doub:36485.0$$R[1]C[9]$userEnteredValue=doub:220.0$$R[1]C[10]$userEnteredValue=str:biweekly$$R[2]C[-8]$userEnteredValue=str:moved$$R[2]C[-7]$userEnteredValue=doub:250.0$$R[2]C[-6]$userEnteredValue=empty$$R[2]C[-5]$userEnteredValue=empty$$R[2]C[-4]$userEnteredValue=empty$$R[2]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[2]C[-2]$userEnteredValue=empty$$R[2]C[-1]$userEnteredValue=empty$$R[2]C[0]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[2]C[1]$userEnteredValue=str:$260 bi-weekly due 11/24 & 12/8.  missed 11/24 rent$$R[2]C[2]$userEnteredValue=str:2/1$$R[2]C[3]$userEnteredValue=doub:2.0$$R[2]C[4]$userEnteredValue=doub:1.0$$R[2]C[5]$userEnteredValue=str:Colonial Manor(Nurse Asst.)$$R[2]C[6]$userEnteredValue=doub:190.0$$R[2]C[7]$userEnteredValue=doub:36784.0$$R[2]C[8]$userEnteredValue=doub:36965.0$$R[2]C[9]$userEnteredValue=doub:130.0$$R[2]C[10]$userEnteredValue=str:weekly$$R[3]C[-8]$userEnteredValue=str:Doris Copeland$$R[3]C[-7]$userEnteredValue=doub:0.0$$R[3]C[-6]$userEnteredValue=empty$$R[3]C[-5]$userEnteredValue=empty$$R[3]C[-4]$userEnteredValue=empty$$R[3]C[-3]$formula=RANGE SUM FORMULA_START, formulaTo ...
# <tf.Tensor: shape=(), dtype=string, numpy=b"\n\xf1c\n&\n\x07formula\x12\x1b\n\x19\n\x17RANGE SUM FORMULA_START\n\x1e\n\x0ecomputed_value\x12\x0c\n\n\n\x08doub:0.0\n\xc1_\n\x0ccontext_data\x12\xb0_\n\xad_\n\xaa_$R[-1]C[-5]$userEnteredValue=str:vacant 11/24$$R[-1]C[-4]$userEnteredValue=empty$$R[-1]C[-3]$userEnteredValue=empty$$R[-1]C[-2]$userEnteredValue=empty$$R[-1]C[-1]$userEnteredValue=empty$$R[-1]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-1]C[1]$userEnteredValue=empty$$R[-1]C[2]$userEnteredValue=empty$$R[-1]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-1]C[4]$userEnteredValue=empty$$R[-1]C[5]$userEnteredValue=str:1/1$$R[-1]C[6]$userEnteredValue=doub:0.0$$R[-1]C[7]$userEnteredValue=empty$$R[-1]C[8]$userEnteredValue=str:Huck-Jacobson$$R[-1]C[9]$userEnteredValue=doub:175.0$$R[-1]C[10]$userEnteredValue=doub:36704.0$$R[0]C[-5]$userEnteredValue=str:Rudy Longoria$$R[0]C[-4]$userEnteredValue=doub:0.0$$R[0]C[-3]$userEnteredValue=empty$$R[0]C[-2]$userEnteredValue=empty$$R[0]C[-1]$userEnteredValue=empty$$R[0]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[0]C[1]$userEnteredValue=empty$$R[0]C[2]$userEnteredValue=empty$$R[0]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[0]C[4]$userEnteredValue=str:220 bi-week 12/8 & 12/15$$R[0]C[5]$userEnteredValue=str:eff$$R[0]C[6]$userEnteredValue=doub:1.0$$R[0]C[7]$userEnteredValue=empty$$R[0]C[8]$userEnteredValue=empty$$R[0]C[9]$userEnteredValue=doub:175.0$$R[0]C[10]$userEnteredValue=doub:36301.0$$R[1]C[-5]$userEnteredValue=str:moved$$R[1]C[-4]$userEnteredValue=doub:250.0$$R[1]C[-3]$userEnteredValue=empty$$R[1]C[-2]$userEnteredValue=empty$$R[1]C[-1]$userEnteredValue=empty$$R[1]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[1]C[1]$userEnteredValue=empty$$R[1]C[2]$userEnteredValue=empty$$R[1]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[1]C[4]$userEnteredValue=str:$260 bi-weekly due 11/24 & 12/8.  missed 11/24 rent$$R[1]C[5]$userEnteredValue=str:2/1$$R[1]C[6]$userEnteredValue=doub:2.0$$R[1]C[7]$userEnteredValue=doub:1.0$$R[1]C[8]$userEnteredValue=str:Colonial Manor(Nurse Asst.)$$R[1]C[9]$userEnteredValue=doub:190.0$$R[1]C[10]$userEnteredValue=doub:36784.0$$R[2]C[-5]$userEnteredValue=str:Doris Copeland$$R[2]C[-4]$userEnteredValue=doub:0.0$$R[2]C[-3]$userEnteredValue=empty$$R[2]C[-2]$userEnteredValue=empty$$R[2]C[-1]$userEnteredValue=empty$$R[2]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[2]C[1]$userEnteredValue=empty$$R[2]C[2]$userEnteredValue=empty$$R[2]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedV ...
# <tf.Tensor: shape=(), dtype=string, numpy=b"\n\x96o\n\x0e\n\x06doc_id\x12\x04\n\x02\n\x00\n\xc6j\n\x0ccontext_data\x12\xb5j\n\xb2j\n\xafj$R[-1]C[-8]$userEnteredValue=str:vacant 11/24$$R[-1]C[-7]$userEnteredValue=empty$$R[-1]C[-6]$userEnteredValue=empty$$R[-1]C[-5]$userEnteredValue=empty$$R[-1]C[-4]$userEnteredValue=empty$$R[-1]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-1]C[-2]$userEnteredValue=empty$$R[-1]C[-1]$userEnteredValue=empty$$R[-1]C[0]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-1]C[1]$userEnteredValue=empty$$R[-1]C[2]$userEnteredValue=str:1/1$$R[-1]C[3]$userEnteredValue=doub:0.0$$R[-1]C[4]$userEnteredValue=empty$$R[-1]C[5]$userEnteredValue=str:Huck-Jacobson$$R[-1]C[6]$userEnteredValue=doub:175.0$$R[-1]C[7]$userEnteredValue=doub:36704.0$$R[-1]C[8]$userEnteredValue=doub:36887.0$$R[-1]C[9]$userEnteredValue=doub:120.0$$R[-1]C[10]$userEnteredValue=str:weekly$$R[0]C[-8]$userEnteredValue=str:Rudy Longoria$$R[0]C[-7]$userEnteredValue=doub:0.0$$R[0]C[-6]$userEnteredValue=empty$$R[0]C[-5]$userEnteredValue=empty$$R[0]C[-4]$userEnteredValue=empty$$R[0]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[0]C[-2]$userEnteredValue=empty$$R[0]C[-1]$userEnteredValue=empty$$R[0]C[0]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[0]C[1]$userEnteredValue=str:220 bi-week 12/8 & 12/15$$R[0]C[2]$userEnteredValue=str:eff$$R[0]C[3]$userEnteredValue=doub:1.0$$R[0]C[4]$userEnteredValue=empty$$R[0]C[5]$userEnteredValue=empty$$R[0]C[6]$userEnteredValue=doub:175.0$$R[0]C[7]$userEnteredValue=doub:36301.0$$R[0]C[8]$userEnteredValue=doub:36485.0$$R[0]C[9]$userEnteredValue=doub:220.0$$R[0]C[10]$userEnteredValue=str:biweekly$$R[1]C[-8]$userEnteredValue=str:moved$$R[1]C[-7]$userEnteredValue=doub:250.0$$R[1]C[-6]$userEnteredValue=empty$$R[1]C[-5]$userEnteredValue=empty$$R[1]C[-4]$userEnteredValue=empty$$R[1]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[1]C[-2]$userEnteredValue=empty$$R[1]C[-1]$userEnteredValue=empty$$R[1]C[0]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[1]C[1]$userEnteredValue=str:$260 bi-weekly due 11/24 & 12/8.  missed 11/24 rent$$R[1]C[2]$userEnteredValue=str:2/1$$R[1]C[3]$userEnteredValue=doub:2.0$$R[1]C[4]$userEnteredValue=doub:1.0$$R[1]C[5]$userEnteredValue=str:Colonial Manor(Nurse Asst.)$$R[1]C[6]$userEnteredValue=doub:190.0$$R[1]C[7]$userEnteredValue=doub:36784.0$$R[1]C[8]$userEnteredValue=doub:36965.0$$R[1]C[9]$userEnteredValue=doub:130.0$$R[1]C[10]$userEnteredValue=str:weekly$$R[2]C[-8]$userEnteredValue=str:Doris Copeland$$R[2]C[-7]$userEnteredValue=doub:0.0$$R[2]C[-6]$userEnteredValue=empty$$R[2]C[-5]$userEnteredValue=empty$$R[2]C[-4]$userEnteredValue=empty$$R[2]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[2]C[-2]$userEnteredValue=empty$$R[2]C[-1 ...
# <tf.Tensor: shape=(), dtype=string, numpy=b"\n\xf9k\n\x0e\n\x06doc_id\x12\x04\n\x02\n\x00\n\x12\n\tcol_index\x12\x05\x1a\x03\n\x01\t\n&\n\x07formula\x12\x1b\n\x19\n\x17RANGE SUM FORMULA_START\n\xae\x02\n\x0econtext_header\x12\x9b\x02\n\x98\x02\n\x95\x02$C[-5]$Util. Over$C[-4]$Total$C[-3]$Date Pd.$C[-2]$Amt. Paid$C[-1]$Fwd. Bal.$C[0]$Notes$C[1]$Br/Ba$C[2]$Adult/Occup$C[3]$Child/Occup$C[4]$Child/Workplace(Position)$C[5]$Child/Deposit$C[6]$Child/Move In$C[7]$Child/Lease Exp$C[8]$Child/Rent$C[9]$Child/Frequency$C[10]$Child/Lease\n,\n\x12formula_token_list\x12\x16\n\x14\n\x12b'=SUM(  RANGE ) '\n\x15\n\x0crecord_index\x12\x05\x1a\x03\n\x01\x02\n \n\x0ecomputed_value\x12\x0e\n\x0c\n\ndoub:250.0\n!\n\x06ranges\x12\x17\n\x15\n\x13R[0]C[-4]:R[0]C[-1]\n\x13\n\x06header\x12\t\n\x07\n\x05Notes\n\xc7g\n\x0ccontext_data\x12\xb6g\n\xb3g\n\xb0g$R[-2]C[-5]$userEnteredValue=str:vacant 11/24$$R[-2]C[-4]$userEnteredValue=empty$$R[-2]C[-3]$userEnteredValue=empty$$R[-2]C[-2]$userEnteredValue=empty$$R[-2]C[-1]$userEnteredValue=empty$$R[-2]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-2]C[1]$userEnteredValue=empty$$R[-2]C[2]$userEnteredValue=empty$$R[-2]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-2]C[4]$userEnteredValue=empty$$R[-2]C[5]$userEnteredValue=str:1/1$$R[-2]C[6]$userEnteredValue=doub:0.0$$R[-2]C[7]$userEnteredValue=empty$$R[-2]C[8]$userEnteredValue=str:Huck-Jacobson$$R[-2]C[9]$userEnteredValue=doub:175.0$$R[-2]C[10]$userEnteredValue=doub:36704.0$$R[-1]C[-5]$userEnteredValue=str:Rudy Longoria$$R[-1]C[-4]$userEnteredValue=doub:0.0$$R[-1]C[-3]$userEnteredValue=empty$$R[-1]C[-2]$userEnteredValue=empty$$R[-1]C[-1]$userEnteredValue=empty$$R[-1]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-1]C[1]$userEnteredValue=empty$$R[-1]C[2]$userEnteredValue=empty$$R[-1]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-1]C[4]$userEnteredValue=str:220 bi-week 12/8 & 12/15$$R[-1]C[5]$userEnteredValue=str:eff$$R[-1]C[6]$userEnteredValue=doub:1.0$$R[-1]C[7]$userEnteredValue=empty$$R[-1]C[8]$userEnteredValue=empty$$R[-1]C[9]$userEnteredValue=doub:175.0$$R[-1]C[10]$userEnteredValue=doub:36301.0$$R[0]C[-5]$userEnteredValue=str:moved$$R[0]C[-4]$userEnteredValue=doub:250.0$$R[0]C[-3]$userEnteredValue=empty$$R[0]C[-2]$userEnteredValue=empty$$R[0]C[-1]$userEnteredValue=empty$$R[0]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[0]C[1]$userEnteredValue=empty$$R[0]C[2]$userEnteredValue=empty$$R[0]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[0]C[4]$userEnteredValue=str:$260 bi-weekly due 11/24 & 12/8.  missed 11/24 rent$$R[0]C[5]$userEnteredValue=str:2/1$$R[0]C[6]$userEnteredValue=doub:2.0$$R[0]C[7]$userEnteredValue=doub:1.0$$R[0]C[8]$userEnteredValue=str:Colonial Manor(Nurse Asst.)$$R[0]C[9]$userEnteredValue=doub:190.0$$R[0]C[10]$userEnteredValue=doub:36784.0$$R[1]C[-5]$userEnteredValue=str:Doris Copeland$$R[1]C[-4]$userEnteredValue= ...
# <tf.Tensor: shape=(), dtype=string, numpy=b"\n\x98x\n \n\x0ecomputed_value\x12\x0e\n\x0c\n\ndoub:250.0\n\x12\n\tcol_index\x12\x05\x1a\x03\n\x01\x0c\n\x0e\n\x06doc_id\x12\x04\n\x02\n\x00\n\x19\n\x06header\x12\x0f\n\r\n\x0bChild/Occup\n!\n\x06ranges\x12\x17\n\x15\n\x13R[0]C[-3] R[0]C[-1]\n\x15\n\x0crecord_index\x12\x05\x1a\x03\n\x01\x02\n\xc3\x02\n\x0econtext_header\x12\xb0\x02\n\xad\x02\n\xaa\x02$C[-8]$Util. Over$C[-7]$Total$C[-6]$Date Pd.$C[-5]$Amt. Paid$C[-4]$Fwd. Bal.$C[-3]$Notes$C[-2]$Br/Ba$C[-1]$Adult/Occup$C[0]$Child/Occup$C[1]$Child/Workplace(Position)$C[2]$Child/Deposit$C[3]$Child/Move In$C[4]$Child/Lease Exp$C[5]$Child/Rent$C[6]$Child/Frequency$C[7]$Child/Lease$C[8]$$C[9]$$C[10]$\n\xc6s\n\x0ccontext_data\x12\xb5s\n\xb2s\n\xafs$R[-2]C[-8]$userEnteredValue=str:vacant 11/24$$R[-2]C[-7]$userEnteredValue=empty$$R[-2]C[-6]$userEnteredValue=empty$$R[-2]C[-5]$userEnteredValue=empty$$R[-2]C[-4]$userEnteredValue=empty$$R[-2]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-2]C[-2]$userEnteredValue=empty$$R[-2]C[-1]$userEnteredValue=empty$$R[-2]C[0]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-2]C[1]$userEnteredValue=empty$$R[-2]C[2]$userEnteredValue=str:1/1$$R[-2]C[3]$userEnteredValue=doub:0.0$$R[-2]C[4]$userEnteredValue=empty$$R[-2]C[5]$userEnteredValue=str:Huck-Jacobson$$R[-2]C[6]$userEnteredValue=doub:175.0$$R[-2]C[7]$userEnteredValue=doub:36704.0$$R[-2]C[8]$userEnteredValue=doub:36887.0$$R[-2]C[9]$userEnteredValue=doub:120.0$$R[-2]C[10]$userEnteredValue=str:weekly$$R[-1]C[-8]$userEnteredValue=str:Rudy Longoria$$R[-1]C[-7]$userEnteredValue=doub:0.0$$R[-1]C[-6]$userEnteredValue=empty$$R[-1]C[-5]$userEnteredValue=empty$$R[-1]C[-4]$userEnteredValue=empty$$R[-1]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-1]C[-2]$userEnteredValue=empty$$R[-1]C[-1]$userEnteredValue=empty$$R[-1]C[0]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-1]C[1]$userEnteredValue=str:220 bi-week 12/8 & 12/15$$R[-1]C[2]$userEnteredValue=str:eff$$R[-1]C[3]$userEnteredValue=doub:1.0$$R[-1]C[4]$userEnteredValue=empty$$R[-1]C[5]$userEnteredValue=empty$$R[-1]C[6]$userEnteredValue=doub:175.0$$R[-1]C[7]$userEnteredValue=doub:36301.0$$R[-1]C[8]$userEnteredValue=doub:36485.0$$R[-1]C[9]$userEnteredValue=doub:220.0$$R[-1]C[10]$userEnteredValue=str:biweekly$$R[0]C[-8]$userEnteredValue=str:moved$$R[0]C[-7]$userEnteredValue=doub:250.0$$R[0]C[-6]$userEnteredValue=empty$$R[0]C[-5]$userEnteredValue=empty$$R[0]C[-4]$userEnteredValue=empty$$R[0]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[0]C[-2]$userEnteredValue=empty$$R[0]C[-1]$userEnteredValue=empty$$R[0]C[0]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[0]C[1]$userEnteredValue=str:$260 bi-weekly due 11/24 & 12/8.  missed 11/24 rent$$R[0]C[2]$userEnteredValue=str:2/1$$R[0]C[3]$userEnteredValue=doub:2.0$$R[0]C[4]$userEnteredValue=doub:1.0$$R[0]C[5]$userEnteredValue=str:Colonial Manor(Nurse Asst.)$ ...
# <tf.Tensor: shape=(), dtype=string, numpy=b"\n\x84t\n\x0e\n\x06doc_id\x12\x04\n\x02\n\x00\n&\n\x07formula\x12\x1b\n\x19\n\x17RANGE SUM FORMULA_START\n\x15\n\x0crecord_index\x12\x05\x1a\x03\n\x01\x03\n!\n\x06ranges\x12\x17\n\x15\n\x13R[0]C[-4]:R[0]C[-1]\n,\n\x12formula_token_list\x12\x16\n\x14\n\x12b'=SUM(  RANGE ) '\n\xd4o\n\x0ccontext_data\x12\xc3o\n\xc0o\n\xbdo$R[-3]C[-5]$userEnteredValue=str:vacant 11/24$$R[-3]C[-4]$userEnteredValue=empty$$R[-3]C[-3]$userEnteredValue=empty$$R[-3]C[-2]$userEnteredValue=empty$$R[-3]C[-1]$userEnteredValue=empty$$R[-3]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-3]C[1]$userEnteredValue=empty$$R[-3]C[2]$userEnteredValue=empty$$R[-3]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-3]C[4]$userEnteredValue=empty$$R[-3]C[5]$userEnteredValue=str:1/1$$R[-3]C[6]$userEnteredValue=doub:0.0$$R[-3]C[7]$userEnteredValue=empty$$R[-3]C[8]$userEnteredValue=str:Huck-Jacobson$$R[-3]C[9]$userEnteredValue=doub:175.0$$R[-3]C[10]$userEnteredValue=doub:36704.0$$R[-2]C[-5]$userEnteredValue=str:Rudy Longoria$$R[-2]C[-4]$userEnteredValue=doub:0.0$$R[-2]C[-3]$userEnteredValue=empty$$R[-2]C[-2]$userEnteredValue=empty$$R[-2]C[-1]$userEnteredValue=empty$$R[-2]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-2]C[1]$userEnteredValue=empty$$R[-2]C[2]$userEnteredValue=empty$$R[-2]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-2]C[4]$userEnteredValue=str:220 bi-week 12/8 & 12/15$$R[-2]C[5]$userEnteredValue=str:eff$$R[-2]C[6]$userEnteredValue=doub:1.0$$R[-2]C[7]$userEnteredValue=empty$$R[-2]C[8]$userEnteredValue=empty$$R[-2]C[9]$userEnteredValue=doub:175.0$$R[-2]C[10]$userEnteredValue=doub:36301.0$$R[-1]C[-5]$userEnteredValue=str:moved$$R[-1]C[-4]$userEnteredValue=doub:250.0$$R[-1]C[-3]$userEnteredValue=empty$$R[-1]C[-2]$userEnteredValue=empty$$R[-1]C[-1]$userEnteredValue=empty$$R[-1]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[-1]C[1]$userEnteredValue=empty$$R[-1]C[2]$userEnteredValue=empty$$R[-1]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[-1]C[4]$userEnteredValue=str:$260 bi-weekly due 11/24 & 12/8.  missed 11/24 rent$$R[-1]C[5]$userEnteredValue=str:2/1$$R[-1]C[6]$userEnteredValue=doub:2.0$$R[-1]C[7]$userEnteredValue=doub:1.0$$R[-1]C[8]$userEnteredValue=str:Colonial Manor(Nurse Asst.)$$R[-1]C[9]$userEnteredValue=doub:190.0$$R[-1]C[10]$userEnteredValue=doub:36784.0$$R[0]C[-5]$userEnteredValue=str:Doris Copeland$$R[0]C[-4]$userEnteredValue=doub:0.0$$R[0]C[-3]$userEnteredValue=empty$$R[0]C[-2]$userEnteredValue=empty$$R[0]C[-1]$userEnteredValue=empty$$R[0]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[0]C[1]$userEnteredValue=empty$$R[0]C[2]$userEnteredValue=empty$$R[0]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ...

# %%
# Create a description of the features.
feature_description = {
    'table_id': tf.io.FixedLenFeature([], tf.int64),
    'doc_id': tf.io.FixedLenFeature([], tf.string),
    'record_index': tf.io.FixedLenFeature([], tf.int64),
    'col_index': tf.io.FixedLenFeature([], tf.int64),
    'formula': tf.io.FixedLenFeature([], tf.string),
    'formula_token_list': tf.io.FixedLenFeature([], tf.string),
    'ranges': tf.io.FixedLenFeature([], tf.string),
    'computed_value': tf.io.FixedLenFeature([], tf.string),
    'header': tf.io.FixedLenFeature([], tf.string),
    'context_header': tf.io.FixedLenFeature([], tf.string),
    'context_data': tf.io.FixedLenFeature([], tf.string)
}

def _parse_example(example_proto):
  # Parse the input `tf.train.Example` proto using the dictionary above.
  return tf.io.parse_single_example(example_proto, feature_description)

parsed_dataset = raw_dataset.map(_parse_example)

dataset
# Out:
# <MapDataset shapes: {col_index: (), computed_value: (), context_data: (21, 21), context_header: (21,), doc_id: (), formula: (), formula_token_list: (), header: (), ranges: (), record_index: (), table_id: ()}, types: {col_index: tf.int64, computed_value: tf.string, context_data: tf.string, context_header: tf.string, doc_id: tf.string, formula: tf.string, formula_token_list: tf.string, header: tf.string, ranges: tf.string, record_index: tf.int64, table_id: tf.int64}>

# %%
# Show the first 10 observations in datasets.
for parsed_record in parsed_dataset.take(10):
  print(repr(parsed_record))
# Out:
# {'col_index': <tf.Tensor: shape=(), dtype=int64, numpy=19>, 'computed_value': <tf.Tensor: shape=(), dtype=string, numpy=b'doub:83.41666666666667'>, 'context_data': <tf.Tensor: shape=(), dtype=string, numpy=b'$R[-1]C[-10]$userEnteredValue=empty$$R[-1]C[-9]$userEnteredValue=empty$$R[-1]C[-8]$userEnteredValue=empty$$R[-1]C[-7]$userEnteredValue=empty$$R[-1]C[-6]$userEnteredValue=empty$$R[-1]C[-5]$userEnteredValue=empty$$R[-1]C[-4]$userEnteredValue=empty$$R[-1]C[-3]$userEnteredValue=empty$$R[-1]C[-2]$userEnteredValue=empty$$R[-1]C[-1]$userEnteredValue=empty$$R[-1]C[0]$userEnteredValue=empty$$R[-1]C[1]$userEnteredValue=empty$$R[-1]C[2]$userEnteredValue=empty$$R[-1]C[3]$userEnteredValue=empty$$R[-1]C[4]$userEnteredValue=empty$$R[0]C[-10]$userEnteredValue=str:New$$R[0]C[-9]$userEnteredValue=doub:37165.0$$R[0]C[-8]$userEnteredValue=str:Whitewing$$R[0]C[-7]$userEnteredValue=str:$4.5MM DASHed$$R[0]C[-6]$userEnteredValue=str:N$$R[0]C[-5]$userEnteredValue=str:N/A$$R[0]C[-4]$userEnteredValue=str:EWS$$R[0]C[-3]$userEnteredValue=str:John Chappell$$R[0]C[-2]$userEnteredValue=str:Stephen Heck$$R[0]C[-1]$userEnteredValue=str:Sale in Process$$R[0]C[0]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[3]C[-17], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:83.41666666666667$$R[0]C[1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[3]C[13], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:54.220833333333346$$R[0]C[2]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[4]C[12], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:49.215833333333336$$R[0]C[3]$userEnteredValue=empty$$R[0]C[4]$userEnteredValue=str:DASH in progress.$$R[1]C[-10]$userEnteredValue=str:New$$R[1]C[-9]$userEnteredValue=doub:37196.0$$R[1]C[-8]$userEnteredValue=str:Whitewing$$R[1]C[-7]$userEnteredValue=str:$4.5MM DASHed$$R[1]C[-6]$userEnteredValue=str:N$$R[1]C[-5]$userEnteredValue=str:N/A$$R[1]C[-4]$userEnteredValue=str:EWS$$R[1]C[-3]$userEnteredValue=str:John Chappell$$R[1]C[-2]$userEnteredValue=str:Stephen Heck$$R[1]C[-1]$userEnteredValue=str:Sale in Process$$R[1]C[0]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[10]C[-17], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:83.41666666666667$$R[1]C[1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[10]C[13], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:54.220833333333346$$R[1]C[2]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[11]C[12], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:49.215833333333336$$R[1]C[3]$userEnteredValue=empty$$R[1]C[4]$userEnteredValue=str:DASH in progress.$$R[2]C[-10]$userEnteredValue=str:New$$R[2]C[-9]$userEnteredValue=doub:37226.0$$R[2]C[-8]$userEnteredValue=str:Whitewing$$R[2]C[-7]$userEnteredValue=str:$4.5MM DASHed$$R[2]C[-6]$userEnteredValue=str:N$$R[2]C[-5]$userEnteredValue=str:N/A$$R[2]C[-4]$userEnteredValue=str:EWS$$R[2]C[-3]$userEnteredValue=str:John Chappell$$R[2]C[-2]$userEnteredValue=str:Stephen Heck$$R[2]C[-1]$userEnteredValue=str:Sale in Process$$R[2]C[0]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[17]C[-17], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:83.41666666666667$$R[2]C[1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[17]C[13], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:54.220833333333346$$R[2]C[2]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[18]C[12], startTokenIndex=2, work ...
# {'col_index': <tf.Tensor: shape=(), dtype=int64, numpy=20>, 'computed_value': <tf.Tensor: shape=(), dtype=string, numpy=b'doub:54.220833333333346'>, 'context_data': <tf.Tensor: shape=(), dtype=string, numpy=b'$R[-1]C[-10]$userEnteredValue=empty$$R[-1]C[-9]$userEnteredValue=empty$$R[-1]C[-8]$userEnteredValue=empty$$R[-1]C[-7]$userEnteredValue=empty$$R[-1]C[-6]$userEnteredValue=empty$$R[-1]C[-5]$userEnteredValue=empty$$R[-1]C[-4]$userEnteredValue=empty$$R[-1]C[-3]$userEnteredValue=empty$$R[-1]C[-2]$userEnteredValue=empty$$R[-1]C[-1]$userEnteredValue=empty$$R[-1]C[0]$userEnteredValue=empty$$R[-1]C[1]$userEnteredValue=empty$$R[-1]C[2]$userEnteredValue=empty$$R[-1]C[3]$userEnteredValue=empty$$R[0]C[-10]$userEnteredValue=doub:37165.0$$R[0]C[-9]$userEnteredValue=str:Whitewing$$R[0]C[-8]$userEnteredValue=str:$4.5MM DASHed$$R[0]C[-7]$userEnteredValue=str:N$$R[0]C[-6]$userEnteredValue=str:N/A$$R[0]C[-5]$userEnteredValue=str:EWS$$R[0]C[-4]$userEnteredValue=str:John Chappell$$R[0]C[-3]$userEnteredValue=str:Stephen Heck$$R[0]C[-2]$userEnteredValue=str:Sale in Process$$R[0]C[-1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[3]C[-17], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:83.41666666666667$$R[0]C[0]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[3]C[13], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:54.220833333333346$$R[0]C[1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[4]C[12], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:49.215833333333336$$R[0]C[2]$userEnteredValue=empty$$R[0]C[3]$userEnteredValue=str:DASH in progress.$$R[1]C[-10]$userEnteredValue=doub:37196.0$$R[1]C[-9]$userEnteredValue=str:Whitewing$$R[1]C[-8]$userEnteredValue=str:$4.5MM DASHed$$R[1]C[-7]$userEnteredValue=str:N$$R[1]C[-6]$userEnteredValue=str:N/A$$R[1]C[-5]$userEnteredValue=str:EWS$$R[1]C[-4]$userEnteredValue=str:John Chappell$$R[1]C[-3]$userEnteredValue=str:Stephen Heck$$R[1]C[-2]$userEnteredValue=str:Sale in Process$$R[1]C[-1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[10]C[-17], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:83.41666666666667$$R[1]C[0]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[10]C[13], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:54.220833333333346$$R[1]C[1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[11]C[12], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:49.215833333333336$$R[1]C[2]$userEnteredValue=empty$$R[1]C[3]$userEnteredValue=str:DASH in progress.$$R[2]C[-10]$userEnteredValue=doub:37226.0$$R[2]C[-9]$userEnteredValue=str:Whitewing$$R[2]C[-8]$userEnteredValue=str:$4.5MM DASHed$$R[2]C[-7]$userEnteredValue=str:N$$R[2]C[-6]$userEnteredValue=str:N/A$$R[2]C[-5]$userEnteredValue=str:EWS$$R[2]C[-4]$userEnteredValue=str:John Chappell$$R[2]C[-3]$userEnteredValue=str:Stephen Heck$$R[2]C[-2]$userEnteredValue=str:Sale in Process$$R[2]C[-1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[17]C[-17], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:83.41666666666667$$R[2]C[0]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[17]C[13], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:54.220833333333346$$R[2]C[1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[18]C[12], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:49.215833333333336$$R[2]C[2]$userEnteredValue=empty$$R[2]C[3]$userEnteredValue=str:DASH in progress ...
# {'col_index': <tf.Tensor: shape=(), dtype=int64, numpy=21>, 'computed_value': <tf.Tensor: shape=(), dtype=string, numpy=b'doub:49.215833333333336'>, 'context_data': <tf.Tensor: shape=(), dtype=string, numpy=b'$R[-1]C[-10]$userEnteredValue=empty$$R[-1]C[-9]$userEnteredValue=empty$$R[-1]C[-8]$userEnteredValue=empty$$R[-1]C[-7]$userEnteredValue=empty$$R[-1]C[-6]$userEnteredValue=empty$$R[-1]C[-5]$userEnteredValue=empty$$R[-1]C[-4]$userEnteredValue=empty$$R[-1]C[-3]$userEnteredValue=empty$$R[-1]C[-2]$userEnteredValue=empty$$R[-1]C[-1]$userEnteredValue=empty$$R[-1]C[0]$userEnteredValue=empty$$R[-1]C[1]$userEnteredValue=empty$$R[-1]C[2]$userEnteredValue=empty$$R[0]C[-10]$userEnteredValue=str:Whitewing$$R[0]C[-9]$userEnteredValue=str:$4.5MM DASHed$$R[0]C[-8]$userEnteredValue=str:N$$R[0]C[-7]$userEnteredValue=str:N/A$$R[0]C[-6]$userEnteredValue=str:EWS$$R[0]C[-5]$userEnteredValue=str:John Chappell$$R[0]C[-4]$userEnteredValue=str:Stephen Heck$$R[0]C[-3]$userEnteredValue=str:Sale in Process$$R[0]C[-2]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[3]C[-17], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:83.41666666666667$$R[0]C[-1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[3]C[13], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:54.220833333333346$$R[0]C[0]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[4]C[12], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:49.215833333333336$$R[0]C[1]$userEnteredValue=empty$$R[0]C[2]$userEnteredValue=str:DASH in progress.$$R[1]C[-10]$userEnteredValue=str:Whitewing$$R[1]C[-9]$userEnteredValue=str:$4.5MM DASHed$$R[1]C[-8]$userEnteredValue=str:N$$R[1]C[-7]$userEnteredValue=str:N/A$$R[1]C[-6]$userEnteredValue=str:EWS$$R[1]C[-5]$userEnteredValue=str:John Chappell$$R[1]C[-4]$userEnteredValue=str:Stephen Heck$$R[1]C[-3]$userEnteredValue=str:Sale in Process$$R[1]C[-2]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[10]C[-17], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:83.41666666666667$$R[1]C[-1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[10]C[13], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:54.220833333333346$$R[1]C[0]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[11]C[12], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:49.215833333333336$$R[1]C[1]$userEnteredValue=empty$$R[1]C[2]$userEnteredValue=str:DASH in progress.$$R[2]C[-10]$userEnteredValue=str:Whitewing$$R[2]C[-9]$userEnteredValue=str:$4.5MM DASHed$$R[2]C[-8]$userEnteredValue=str:N$$R[2]C[-7]$userEnteredValue=str:N/A$$R[2]C[-6]$userEnteredValue=str:EWS$$R[2]C[-5]$userEnteredValue=str:John Chappell$$R[2]C[-4]$userEnteredValue=str:Stephen Heck$$R[2]C[-3]$userEnteredValue=str:Sale in Process$$R[2]C[-2]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[17]C[-17], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:83.41666666666667$$R[2]C[-1]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[17]C[13], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:54.220833333333346$$R[2]C[0]$formula=RANGE UPLUS FORMULA_START, formulaTokenList==+ RANGE, ranges=[R1C1FormulaRange{relativeRange=G278457581!R[18]C[12], startTokenIndex=2, workbookRangeId=null}], computedValue=doub:49.215833333333336$$R[2]C[1]$userEnteredValue=empty$$R[2]C[2]$userEnteredValue=str:DASH in progress.$$R[3]C[-10]$userEnteredValue=str:ENE B/S$$R[3]C[-9]$userEnteredValue=str:Approved$$R[3]C[-8]$userEnteredValue=str:N$$R[3]C[-7]$userEnteredValue=str:N/A$ ...
# {'col_index': <tf.Tensor: shape=(), dtype=int64, numpy=9>, 'computed_value': <tf.Tensor: shape=(), dtype=string, numpy=b'doub:0.0'>, 'context_data': <tf.Tensor: shape=(), dtype=string, numpy=b'$R[0]C[-5]$userEnteredValue=str:vacant 11/24$$R[0]C[-4]$userEnteredValue=empty$$R[0]C[-3]$userEnteredValue=empty$$R[0]C[-2]$userEnteredValue=empty$$R[0]C[-1]$userEnteredValue=empty$$R[0]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[0]C[1]$userEnteredValue=empty$$R[0]C[2]$userEnteredValue=empty$$R[0]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[0]C[4]$userEnteredValue=empty$$R[0]C[5]$userEnteredValue=str:1/1$$R[0]C[6]$userEnteredValue=doub:0.0$$R[0]C[7]$userEnteredValue=empty$$R[0]C[8]$userEnteredValue=str:Huck-Jacobson$$R[0]C[9]$userEnteredValue=doub:175.0$$R[0]C[10]$userEnteredValue=doub:36704.0$$R[1]C[-5]$userEnteredValue=str:Rudy Longoria$$R[1]C[-4]$userEnteredValue=doub:0.0$$R[1]C[-3]$userEnteredValue=empty$$R[1]C[-2]$userEnteredValue=empty$$R[1]C[-1]$userEnteredValue=empty$$R[1]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[1]C[1]$userEnteredValue=empty$$R[1]C[2]$userEnteredValue=empty$$R[1]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[1]C[4]$userEnteredValue=str:220 bi-week 12/8 & 12/15$$R[1]C[5]$userEnteredValue=str:eff$$R[1]C[6]$userEnteredValue=doub:1.0$$R[1]C[7]$userEnteredValue=empty$$R[1]C[8]$userEnteredValue=empty$$R[1]C[9]$userEnteredValue=doub:175.0$$R[1]C[10]$userEnteredValue=doub:36301.0$$R[2]C[-5]$userEnteredValue=str:moved$$R[2]C[-4]$userEnteredValue=doub:250.0$$R[2]C[-3]$userEnteredValue=empty$$R[2]C[-2]$userEnteredValue=empty$$R[2]C[-1]$userEnteredValue=empty$$R[2]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[2]C[1]$userEnteredValue=empty$$R[2]C[2]$userEnteredValue=empty$$R[2]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[2]C[4]$userEnteredValue=str:$260 bi-weekly due 11/24 & 12/8.  missed 11/24 rent$$R[2]C[5]$userEnteredValue=str:2/1$$R[2]C[6]$userEnteredValue=doub:2.0$$R[2]C[7]$userEnteredValue=doub:1.0$$R[2]C[8]$userEnteredValue=str:Colonial Manor(Nurse Asst.)$$R[2]C[9]$userEnteredValue=doub:190.0$$R[2]C[10]$userEnteredValue=doub:36784.0$$R[3]C[-5]$userEnteredValue=str:Doris Copeland$$R[3]C[-4]$userEnteredValue=doub:0.0$$R[3]C[-3]$userEnteredValue=empty$$R[3]C[-2]$userEnteredValue=empty$$R[3]C[-1]$userEnteredValue=empty$$R[3]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[3]C[1]$userEnteredValue=empty$$R[3]C[2]$userEnteredValue=empty$$R[3]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[3]C[4]$userEnter ...
# {'col_index': <tf.Tensor: shape=(), dtype=int64, numpy=12>, 'computed_value': <tf.Tensor: shape=(), dtype=string, numpy=b'doub:0.0'>, 'context_data': <tf.Tensor: shape=(), dtype=string, numpy=b'$R[0]C[-8]$userEnteredValue=str:vacant 11/24$$R[0]C[-7]$userEnteredValue=empty$$R[0]C[-6]$userEnteredValue=empty$$R[0]C[-5]$userEnteredValue=empty$$R[0]C[-4]$userEnteredValue=empty$$R[0]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[0]C[-2]$userEnteredValue=empty$$R[0]C[-1]$userEnteredValue=empty$$R[0]C[0]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[0]C[1]$userEnteredValue=empty$$R[0]C[2]$userEnteredValue=str:1/1$$R[0]C[3]$userEnteredValue=doub:0.0$$R[0]C[4]$userEnteredValue=empty$$R[0]C[5]$userEnteredValue=str:Huck-Jacobson$$R[0]C[6]$userEnteredValue=doub:175.0$$R[0]C[7]$userEnteredValue=doub:36704.0$$R[0]C[8]$userEnteredValue=doub:36887.0$$R[0]C[9]$userEnteredValue=doub:120.0$$R[0]C[10]$userEnteredValue=str:weekly$$R[1]C[-8]$userEnteredValue=str:Rudy Longoria$$R[1]C[-7]$userEnteredValue=doub:0.0$$R[1]C[-6]$userEnteredValue=empty$$R[1]C[-5]$userEnteredValue=empty$$R[1]C[-4]$userEnteredValue=empty$$R[1]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[1]C[-2]$userEnteredValue=empty$$R[1]C[-1]$userEnteredValue=empty$$R[1]C[0]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[1]C[1]$userEnteredValue=str:220 bi-week 12/8 & 12/15$$R[1]C[2]$userEnteredValue=str:eff$$R[1]C[3]$userEnteredValue=doub:1.0$$R[1]C[4]$userEnteredValue=empty$$R[1]C[5]$userEnteredValue=empty$$R[1]C[6]$userEnteredValue=doub:175.0$$R[1]C[7]$userEnteredValue=doub:36301.0$$R[1]C[8]$userEnteredValue=doub:36485.0$$R[1]C[9]$userEnteredValue=doub:220.0$$R[1]C[10]$userEnteredValue=str:biweekly$$R[2]C[-8]$userEnteredValue=str:moved$$R[2]C[-7]$userEnteredValue=doub:250.0$$R[2]C[-6]$userEnteredValue=empty$$R[2]C[-5]$userEnteredValue=empty$$R[2]C[-4]$userEnteredValue=empty$$R[2]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[2]C[-2]$userEnteredValue=empty$$R[2]C[-1]$userEnteredValue=empty$$R[2]C[0]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[2]C[1]$userEnteredValue=str:$260 bi-weekly due 11/24 & 12/8.  missed 11/24 rent$$R[2]C[2]$userEnteredValue=str:2/1$$R[2]C[3]$userEnteredValue=doub:2.0$$R[2]C[4]$userEnteredValue=doub:1.0$$R[2]C[5]$userEnteredValue=str:Colonial Manor(Nurse Asst.)$$R[2]C[6]$userEnteredValue=doub:190.0$$R[2]C[7]$userEnteredValue=doub:36784.0$$R[2]C[8]$userEnteredValue=doub:36965.0$$R[2]C[9]$userEnteredValue=doub:130.0$$R[2]C[10]$userEnteredValue=str:weekly$$R[3]C[-8]$userEnteredValue=str:Doris Copeland$$R[3]C[-7]$userEnteredValue=doub:0.0$$R[3]C[-6]$userEnteredValue=empty$$R[3]C[-5]$userEnteredValue=empty$$R[3]C[-4]$userEnteredValue=empty$$R[3]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[3] ...
# {'col_index': <tf.Tensor: shape=(), dtype=int64, numpy=9>, 'computed_value': <tf.Tensor: shape=(), dtype=string, numpy=b'doub:0.0'>, 'context_data': <tf.Tensor: shape=(), dtype=string, numpy=b'$R[-1]C[-5]$userEnteredValue=str:vacant 11/24$$R[-1]C[-4]$userEnteredValue=empty$$R[-1]C[-3]$userEnteredValue=empty$$R[-1]C[-2]$userEnteredValue=empty$$R[-1]C[-1]$userEnteredValue=empty$$R[-1]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-1]C[1]$userEnteredValue=empty$$R[-1]C[2]$userEnteredValue=empty$$R[-1]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-1]C[4]$userEnteredValue=empty$$R[-1]C[5]$userEnteredValue=str:1/1$$R[-1]C[6]$userEnteredValue=doub:0.0$$R[-1]C[7]$userEnteredValue=empty$$R[-1]C[8]$userEnteredValue=str:Huck-Jacobson$$R[-1]C[9]$userEnteredValue=doub:175.0$$R[-1]C[10]$userEnteredValue=doub:36704.0$$R[0]C[-5]$userEnteredValue=str:Rudy Longoria$$R[0]C[-4]$userEnteredValue=doub:0.0$$R[0]C[-3]$userEnteredValue=empty$$R[0]C[-2]$userEnteredValue=empty$$R[0]C[-1]$userEnteredValue=empty$$R[0]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[0]C[1]$userEnteredValue=empty$$R[0]C[2]$userEnteredValue=empty$$R[0]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[0]C[4]$userEnteredValue=str:220 bi-week 12/8 & 12/15$$R[0]C[5]$userEnteredValue=str:eff$$R[0]C[6]$userEnteredValue=doub:1.0$$R[0]C[7]$userEnteredValue=empty$$R[0]C[8]$userEnteredValue=empty$$R[0]C[9]$userEnteredValue=doub:175.0$$R[0]C[10]$userEnteredValue=doub:36301.0$$R[1]C[-5]$userEnteredValue=str:moved$$R[1]C[-4]$userEnteredValue=doub:250.0$$R[1]C[-3]$userEnteredValue=empty$$R[1]C[-2]$userEnteredValue=empty$$R[1]C[-1]$userEnteredValue=empty$$R[1]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[1]C[1]$userEnteredValue=empty$$R[1]C[2]$userEnteredValue=empty$$R[1]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[1]C[4]$userEnteredValue=str:$260 bi-weekly due 11/24 & 12/8.  missed 11/24 rent$$R[1]C[5]$userEnteredValue=str:2/1$$R[1]C[6]$userEnteredValue=doub:2.0$$R[1]C[7]$userEnteredValue=doub:1.0$$R[1]C[8]$userEnteredValue=str:Colonial Manor(Nurse Asst.)$$R[1]C[9]$userEnteredValue=doub:190.0$$R[1]C[10]$userEnteredValue=doub:36784.0$$R[2]C[-5]$userEnteredValue=str:Doris Copeland$$R[2]C[-4]$userEnteredValue=doub:0.0$$R[2]C[-3]$userEnteredValue=empty$$R[2]C[-2]$userEnteredValue=empty$$R[2]C[-1]$userEnteredValue=empty$$R[2]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[2]C[1]$userEnteredValue=empty$$R[2]C[2]$userEnteredValue=empty$$R[2]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[ ...
# {'col_index': <tf.Tensor: shape=(), dtype=int64, numpy=12>, 'computed_value': <tf.Tensor: shape=(), dtype=string, numpy=b'doub:0.0'>, 'context_data': <tf.Tensor: shape=(), dtype=string, numpy=b'$R[-1]C[-8]$userEnteredValue=str:vacant 11/24$$R[-1]C[-7]$userEnteredValue=empty$$R[-1]C[-6]$userEnteredValue=empty$$R[-1]C[-5]$userEnteredValue=empty$$R[-1]C[-4]$userEnteredValue=empty$$R[-1]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-1]C[-2]$userEnteredValue=empty$$R[-1]C[-1]$userEnteredValue=empty$$R[-1]C[0]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-1]C[1]$userEnteredValue=empty$$R[-1]C[2]$userEnteredValue=str:1/1$$R[-1]C[3]$userEnteredValue=doub:0.0$$R[-1]C[4]$userEnteredValue=empty$$R[-1]C[5]$userEnteredValue=str:Huck-Jacobson$$R[-1]C[6]$userEnteredValue=doub:175.0$$R[-1]C[7]$userEnteredValue=doub:36704.0$$R[-1]C[8]$userEnteredValue=doub:36887.0$$R[-1]C[9]$userEnteredValue=doub:120.0$$R[-1]C[10]$userEnteredValue=str:weekly$$R[0]C[-8]$userEnteredValue=str:Rudy Longoria$$R[0]C[-7]$userEnteredValue=doub:0.0$$R[0]C[-6]$userEnteredValue=empty$$R[0]C[-5]$userEnteredValue=empty$$R[0]C[-4]$userEnteredValue=empty$$R[0]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[0]C[-2]$userEnteredValue=empty$$R[0]C[-1]$userEnteredValue=empty$$R[0]C[0]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[0]C[1]$userEnteredValue=str:220 bi-week 12/8 & 12/15$$R[0]C[2]$userEnteredValue=str:eff$$R[0]C[3]$userEnteredValue=doub:1.0$$R[0]C[4]$userEnteredValue=empty$$R[0]C[5]$userEnteredValue=empty$$R[0]C[6]$userEnteredValue=doub:175.0$$R[0]C[7]$userEnteredValue=doub:36301.0$$R[0]C[8]$userEnteredValue=doub:36485.0$$R[0]C[9]$userEnteredValue=doub:220.0$$R[0]C[10]$userEnteredValue=str:biweekly$$R[1]C[-8]$userEnteredValue=str:moved$$R[1]C[-7]$userEnteredValue=doub:250.0$$R[1]C[-6]$userEnteredValue=empty$$R[1]C[-5]$userEnteredValue=empty$$R[1]C[-4]$userEnteredValue=empty$$R[1]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[1]C[-2]$userEnteredValue=empty$$R[1]C[-1]$userEnteredValue=empty$$R[1]C[0]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[1]C[1]$userEnteredValue=str:$260 bi-weekly due 11/24 & 12/8.  missed 11/24 rent$$R[1]C[2]$userEnteredValue=str:2/1$$R[1]C[3]$userEnteredValue=doub:2.0$$R[1]C[4]$userEnteredValue=doub:1.0$$R[1]C[5]$userEnteredValue=str:Colonial Manor(Nurse Asst.)$$R[1]C[6]$userEnteredValue=doub:190.0$$R[1]C[7]$userEnteredValue=doub:36784.0$$R[1]C[8]$userEnteredValue=doub:36965.0$$R[1]C[9]$userEnteredValue=doub:130.0$$R[1]C[10]$userEnteredValue=str:weekly$$R[2]C[-8]$userEnteredValue=str:Doris Copeland$$R[2]C[-7]$userEnteredValue=doub:0.0$$R[2]C[-6]$userEnteredValue=empty$$R[2]C[-5]$userEnteredValue=empty$$R[2]C[-4]$userEnteredValue=empty$$R[2]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedV ...
# {'col_index': <tf.Tensor: shape=(), dtype=int64, numpy=9>, 'computed_value': <tf.Tensor: shape=(), dtype=string, numpy=b'doub:250.0'>, 'context_data': <tf.Tensor: shape=(), dtype=string, numpy=b'$R[-2]C[-5]$userEnteredValue=str:vacant 11/24$$R[-2]C[-4]$userEnteredValue=empty$$R[-2]C[-3]$userEnteredValue=empty$$R[-2]C[-2]$userEnteredValue=empty$$R[-2]C[-1]$userEnteredValue=empty$$R[-2]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-2]C[1]$userEnteredValue=empty$$R[-2]C[2]$userEnteredValue=empty$$R[-2]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-2]C[4]$userEnteredValue=empty$$R[-2]C[5]$userEnteredValue=str:1/1$$R[-2]C[6]$userEnteredValue=doub:0.0$$R[-2]C[7]$userEnteredValue=empty$$R[-2]C[8]$userEnteredValue=str:Huck-Jacobson$$R[-2]C[9]$userEnteredValue=doub:175.0$$R[-2]C[10]$userEnteredValue=doub:36704.0$$R[-1]C[-5]$userEnteredValue=str:Rudy Longoria$$R[-1]C[-4]$userEnteredValue=doub:0.0$$R[-1]C[-3]$userEnteredValue=empty$$R[-1]C[-2]$userEnteredValue=empty$$R[-1]C[-1]$userEnteredValue=empty$$R[-1]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-1]C[1]$userEnteredValue=empty$$R[-1]C[2]$userEnteredValue=empty$$R[-1]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-1]C[4]$userEnteredValue=str:220 bi-week 12/8 & 12/15$$R[-1]C[5]$userEnteredValue=str:eff$$R[-1]C[6]$userEnteredValue=doub:1.0$$R[-1]C[7]$userEnteredValue=empty$$R[-1]C[8]$userEnteredValue=empty$$R[-1]C[9]$userEnteredValue=doub:175.0$$R[-1]C[10]$userEnteredValue=doub:36301.0$$R[0]C[-5]$userEnteredValue=str:moved$$R[0]C[-4]$userEnteredValue=doub:250.0$$R[0]C[-3]$userEnteredValue=empty$$R[0]C[-2]$userEnteredValue=empty$$R[0]C[-1]$userEnteredValue=empty$$R[0]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[0]C[1]$userEnteredValue=empty$$R[0]C[2]$userEnteredValue=empty$$R[0]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[0]C[4]$userEnteredValue=str:$260 bi-weekly due 11/24 & 12/8.  missed 11/24 rent$$R[0]C[5]$userEnteredValue=str:2/1$$R[0]C[6]$userEnteredValue=doub:2.0$$R[0]C[7]$userEnteredValue=doub:1.0$$R[0]C[8]$userEnteredValue=str:Colonial Manor(Nurse Asst.)$$R[0]C[9]$userEnteredValue=doub:190.0$$R[0]C[10]$userEnteredValue=doub:36784.0$$R[1]C[-5]$userEnteredValue=str:Doris Copeland$$R[1]C[-4]$userEnteredValue=doub:0.0$$R[1]C[-3]$userEnteredValue=empty$$R[1]C[-2]$userEnteredValue=empty$$R[1]C[-1]$userEnteredValue=empty$$R[1]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[1]C[1]$userEnteredValue=empty$$R[1]C[2]$userEnteredValue=empty$$R[1]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computed ...
# {'col_index': <tf.Tensor: shape=(), dtype=int64, numpy=12>, 'computed_value': <tf.Tensor: shape=(), dtype=string, numpy=b'doub:250.0'>, 'context_data': <tf.Tensor: shape=(), dtype=string, numpy=b'$R[-2]C[-8]$userEnteredValue=str:vacant 11/24$$R[-2]C[-7]$userEnteredValue=empty$$R[-2]C[-6]$userEnteredValue=empty$$R[-2]C[-5]$userEnteredValue=empty$$R[-2]C[-4]$userEnteredValue=empty$$R[-2]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-2]C[-2]$userEnteredValue=empty$$R[-2]C[-1]$userEnteredValue=empty$$R[-2]C[0]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-2]C[1]$userEnteredValue=empty$$R[-2]C[2]$userEnteredValue=str:1/1$$R[-2]C[3]$userEnteredValue=doub:0.0$$R[-2]C[4]$userEnteredValue=empty$$R[-2]C[5]$userEnteredValue=str:Huck-Jacobson$$R[-2]C[6]$userEnteredValue=doub:175.0$$R[-2]C[7]$userEnteredValue=doub:36704.0$$R[-2]C[8]$userEnteredValue=doub:36887.0$$R[-2]C[9]$userEnteredValue=doub:120.0$$R[-2]C[10]$userEnteredValue=str:weekly$$R[-1]C[-8]$userEnteredValue=str:Rudy Longoria$$R[-1]C[-7]$userEnteredValue=doub:0.0$$R[-1]C[-6]$userEnteredValue=empty$$R[-1]C[-5]$userEnteredValue=empty$$R[-1]C[-4]$userEnteredValue=empty$$R[-1]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-1]C[-2]$userEnteredValue=empty$$R[-1]C[-1]$userEnteredValue=empty$$R[-1]C[0]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-1]C[1]$userEnteredValue=str:220 bi-week 12/8 & 12/15$$R[-1]C[2]$userEnteredValue=str:eff$$R[-1]C[3]$userEnteredValue=doub:1.0$$R[-1]C[4]$userEnteredValue=empty$$R[-1]C[5]$userEnteredValue=empty$$R[-1]C[6]$userEnteredValue=doub:175.0$$R[-1]C[7]$userEnteredValue=doub:36301.0$$R[-1]C[8]$userEnteredValue=doub:36485.0$$R[-1]C[9]$userEnteredValue=doub:220.0$$R[-1]C[10]$userEnteredValue=str:biweekly$$R[0]C[-8]$userEnteredValue=str:moved$$R[0]C[-7]$userEnteredValue=doub:250.0$$R[0]C[-6]$userEnteredValue=empty$$R[0]C[-5]$userEnteredValue=empty$$R[0]C[-4]$userEnteredValue=empty$$R[0]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[0]C[-2]$userEnteredValue=empty$$R[0]C[-1]$userEnteredValue=empty$$R[0]C[0]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[0]C[1]$userEnteredValue=str:$260 bi-weekly due 11/24 & 12/8.  missed 11/24 rent$$R[0]C[2]$userEnteredValue=str:2/1$$R[0]C[3]$userEnteredValue=doub:2.0$$R[0]C[4]$userEnteredValue=doub:1.0$$R[0]C[5]$userEnteredValue=str:Colonial Manor(Nurse Asst.)$$R[0]C[6]$userEnteredValue=doub:190.0$$R[0]C[7]$userEnteredValue=doub:36784.0$$R[0]C[8]$userEnteredValue=doub:36965.0$$R[0]C[9]$userEnteredValue=doub:130.0$$R[0]C[10]$userEnteredValue=str:weekly$$R[1]C[-8]$userEnteredValue=str:Doris Copeland$$R[1]C[-7]$userEnteredValue=doub:0.0$$R[1]C[-6]$userEnteredValue=empty$$R[1]C[-5]$userEnteredValue=empty$$R[1]C[-4]$userEnteredValue=empty$$R[1]C[-3]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRang ...
# {'col_index': <tf.Tensor: shape=(), dtype=int64, numpy=9>, 'computed_value': <tf.Tensor: shape=(), dtype=string, numpy=b'doub:0.0'>, 'context_data': <tf.Tensor: shape=(), dtype=string, numpy=b'$R[-3]C[-5]$userEnteredValue=str:vacant 11/24$$R[-3]C[-4]$userEnteredValue=empty$$R[-3]C[-3]$userEnteredValue=empty$$R[-3]C[-2]$userEnteredValue=empty$$R[-3]C[-1]$userEnteredValue=empty$$R[-3]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-3]C[1]$userEnteredValue=empty$$R[-3]C[2]$userEnteredValue=empty$$R[-3]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-3]C[4]$userEnteredValue=empty$$R[-3]C[5]$userEnteredValue=str:1/1$$R[-3]C[6]$userEnteredValue=doub:0.0$$R[-3]C[7]$userEnteredValue=empty$$R[-3]C[8]$userEnteredValue=str:Huck-Jacobson$$R[-3]C[9]$userEnteredValue=doub:175.0$$R[-3]C[10]$userEnteredValue=doub:36704.0$$R[-2]C[-5]$userEnteredValue=str:Rudy Longoria$$R[-2]C[-4]$userEnteredValue=doub:0.0$$R[-2]C[-3]$userEnteredValue=empty$$R[-2]C[-2]$userEnteredValue=empty$$R[-2]C[-1]$userEnteredValue=empty$$R[-2]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-2]C[1]$userEnteredValue=empty$$R[-2]C[2]$userEnteredValue=empty$$R[-2]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[-2]C[4]$userEnteredValue=str:220 bi-week 12/8 & 12/15$$R[-2]C[5]$userEnteredValue=str:eff$$R[-2]C[6]$userEnteredValue=doub:1.0$$R[-2]C[7]$userEnteredValue=empty$$R[-2]C[8]$userEnteredValue=empty$$R[-2]C[9]$userEnteredValue=doub:175.0$$R[-2]C[10]$userEnteredValue=doub:36301.0$$R[-1]C[-5]$userEnteredValue=str:moved$$R[-1]C[-4]$userEnteredValue=doub:250.0$$R[-1]C[-3]$userEnteredValue=empty$$R[-1]C[-2]$userEnteredValue=empty$$R[-1]C[-1]$userEnteredValue=empty$$R[-1]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[-1]C[1]$userEnteredValue=empty$$R[-1]C[2]$userEnteredValue=empty$$R[-1]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:250.0$$R[-1]C[4]$userEnteredValue=str:$260 bi-weekly due 11/24 & 12/8.  missed 11/24 rent$$R[-1]C[5]$userEnteredValue=str:2/1$$R[-1]C[6]$userEnteredValue=doub:2.0$$R[-1]C[7]$userEnteredValue=doub:1.0$$R[-1]C[8]$userEnteredValue=str:Colonial Manor(Nurse Asst.)$$R[-1]C[9]$userEnteredValue=doub:190.0$$R[-1]C[10]$userEnteredValue=doub:36784.0$$R[0]C[-5]$userEnteredValue=str:Doris Copeland$$R[0]C[-4]$userEnteredValue=doub:0.0$$R[0]C[-3]$userEnteredValue=empty$$R[0]C[-2]$userEnteredValue=empty$$R[0]C[-1]$userEnteredValue=empty$$R[0]C[0]$formula=RANGE SUM FORMULA_START, formulaTokenList==SUM( RANGE ), ranges=[R1C1FormulaRange{relativeRange=R[0]C[-4]:R[0]C[-1], startTokenIndex=3, workbookRangeId=null}], computedValue=doub:0.0$$R[0]C[1]$userEnteredValue=empty$$R[0]C[2]$userEnteredValue=empty$$R[0]C[3]$formula=RANGE RANGE - FORMULA_START, formulaTokenList== RANGE - RANGE, ranges=[R1C1FormulaRange{relativeRange=R[0]C[-3], startTokenIndex=1, workbookRangeId=null}, R1C1FormulaRange{relativeRange=R[0]C[-1], startTokenIndex=3, workbookRangeId=nu ...

# %% [markdown]
# <div>
#   <h6 align=center>Dataset</h6>
#
#   <table border="1" class="dataframe">
#     <thead>
#       <tr align=center>
#         <th></th>
#         <th>Train</th>
#         <th>Validation</th>
#         <th>Test</th>
#         <th>Total</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr align=center>
#         <th align=left>#Samples</th>
#         <td>178K</td>
#         <td>41K</td>
#         <td>33K</td>
#         <td>252K</td>
#       </tr>
#     </tbody>
#   </table>
#   <br />
#   <table border="1" class="dataframe">
#     <thead>
#       <tr align=center>
#         <th align=left>Sketch Length</th>
#         <th>2</th>
#         <th>3</th>
#         <th>4-5</th>
#         <th>6-7</th>
#         <th>8+</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr align=center>
#         <th align=left>Distribution</th>
#         <td>55%</td>
#         <td>18%</td>
#         <td>13%</td>
#         <td>9%</td>
#         <td>5%</td>
#       </tr>
#     </tbody>
#   </table>
#   <br />
#   <table border="1" class="dataframe">
#     <thead>
#       <tr align=center>
#         <th></th>
#         <th>Spreadsheet Functions</th>
#         <th>Type</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr align=center>
#         <th align=left>1</th>
#         <td>ADD(+)</td>
#         <td>Operator</td>
#       </tr>
#       <tr align=center>
#         <th align=left>2</th>
#         <td>MINUS(-)</td>
#         <td>Operator</td>
#       </tr>
#       <tr align=center>
#         <th align=left>3</th>
#         <td>MULPTIPLY(*)</td>
#         <td>Operator</td>
#       </tr>
#       <tr align=center>
#         <th align=left>4</th>
#         <td>DIV(/)</td>
#         <td>Operator</td>
#       </tr>
#       <tr align=center>
#         <th align=left>5</th>
#         <td>UPLUS</td>
#         <td>Operator</td>
#       </tr>
#       <tr align=center>
#         <th align=left>6</th>
#         <td>UMINUS</td>
#         <td>Operator</td>
#       </tr>
#       <tr align=center>
#         <th align=left>7</th>
#         <td>SUM</td>
#         <td>Math</td>
#       </tr>
#       <tr align=center>
#         <th align=left>8</th>
#         <td>ABS</td>
#         <td>Math</td>
#       </tr>
#       <tr align=center>
#         <th align=left>9</th>
#         <td>LN</td>
#         <td>Math</td>
#       </tr>
#       <tr align=center>
#         <th align=left>10</th>
#         <td>AVERAGE</td>
#         <td>Statistical</td>
#       </tr>
#       <tr align=center>
#         <th align=left>11</th>
#         <td>MIN</td>
#         <td>Statistical</td>
#       </tr>
#       <tr align=center>
#         <th align=left>12</th>
#         <td>MAX</td>
#         <td>Statistical</td>
#       </tr>
#       <tr align=center>
#         <th align=left>13</th>
#         <td>COUNT</td>
#         <td>Statistical</td>
#       </tr>
#       <tr align=center>
#         <th align=left>14</th>
#         <td>COUNTA</td>
#         <td>Statistical</td>
#       </tr>
#       <tr align=center>
#         <th align=left>15</th>
#         <td>STDEV</td>
#         <td>Statistical</td>
#       </tr>
#       <tr align=center>
#         <th align=left>16</th>
#         <td>DAY</td>
#         <td>Date</td>
#       </tr>
#       <tr align=center>
#         <th align=left>17</th>
#         <td>WEEKDAY</td>
#         <td>Date</td>
#       </tr>
#     </tbody>
#   </table>
# </div>
#
# <br />
#
# <div>
#   <h6 align=center>Result</h6>
#   <table border="1" class="dataframe">
#     <thead>
#       <tr align=center>
#         <th align=left>Dataset</th>
#         <th>Top-1</th>
#         <th>Top-5</th>
#         <th>Top-10</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr align=center>
#         <th align=left>Enron</th>
#         <td>29.8%</td>
#         <td>41.8%</td>
#         <td>48.5%</td>
#       </tr>
#       <tr align=center>
#         <th align=left>Google Sheets</th>
#         <td>42.51%</td>
#         <td>54.41%</td>
#         <td>58.57%</td>
#       </tr>
#     </tbody>
#   </table>
# </div>
